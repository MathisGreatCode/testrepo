# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **MATHIS VARCHAVSKY**
#
# Data Scientist specialized in sports analysis

# %% [markdown]
# *I am interested in data science because I like understanding why things happen the way they do and knowing the impact of different elements on a result. I love having insight.*

# %% [markdown]
# ### simple mathematical operation

# %%
(6 * 6) - 7

# %% [markdown]
# ***
#
# This is an horizontal rule
#
# ***
#
# * This
# * Is
# * A
# * Bullet
# * List
#
# <a href="https://www.ibm.com/" target="_blank">This is an hyperlink for IBM's website</a>
#
# ![Worldcup logo here](https://www.unlockbrands.com/media/1772/fwc-2022-logo.jpg)
